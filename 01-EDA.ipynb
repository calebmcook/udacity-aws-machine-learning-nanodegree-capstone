# %% [markdown]
# # 01 - EDA Notebook

# %%
import pandas as pd
import os
import glob

# %%
data_path = os.path.join(os.getcwd(), 'use_this_data', '*')

# %%
files = glob.glob(data_path)

# %%
files
# Out:
# ['/home/ec2-user/SageMaker/udacity-aws-machine-learning-nanodegree-capstone/use_this_data/watchlist_01012022_10312022',
#  '/home/ec2-user/SageMaker/udacity-aws-machine-learning-nanodegree-capstone/use_this_data/ratios_01012022_10312022',
#  '/home/ec2-user/SageMaker/udacity-aws-machine-learning-nanodegree-capstone/use_this_data/stockquotes_01012022_10312022',
#  '/home/ec2-user/SageMaker/udacity-aws-machine-learning-nanodegree-capstone/use_this_data/shortsales_01012022_10312022']

# %%
wl = pd.read_parquet(files[0])
rat = pd.read_parquet(files[1])
sq = pd.read_parquet(files[2])
ss = pd.read_parquet(files[3])

# %%
wl
# Out:
#    Security Code Periodic Call Auction Trading (see Remark below)  file_date  \
# 0           1213                                                  2022-01-03
# 1           1418                                                  2022-01-03
# 2           1472                                                  2022-01-03
# 3           1512                                               ** 2022-01-03
# 4           1538                                                  2022-01-03
# ..           ...                                              ...        ...
# 8           3043                                               ** 2022-10-31
# 9           3536                                               ** 2022-10-31
# 10          6225                                               ** 2022-10-31
# 11          8101                                               ** 2022-10-31
# 12          9110                                                  2022-10-31
#
#    Security Code Clean
# ...

# %%
rat
# Out:
#     Security Code  Dividend yield (%)  Dividend year  P/E ratio  P/B ratio  \
# 0            1101                7.10           2020      13.91       1.49
# 1            1102                7.86           2020      10.09       1.03
# 2            1103                6.76           2020       7.29       0.51
# 3            1104                5.09           2020      12.78       0.75
# 4            1108                5.88           2020      20.52       1.06
# ..            ...                 ...            ...        ...        ...
# 960          9944                4.90           2021       4.11       0.66
# 961          9945               17.68           2021       5.34       2.96
# 962          9946                5.89           2021      18.33       0.59
# 963          9955                0.00           2021        NaN       1.21
# 964          9958                3.88           2021      19.35       2.54
#
#     Fiscal year / quarter  file_date Security Code Clean
# ...

# %%
sq
# Out:
#      Security Code  Trade Volume  Transaction  Trade Value  Opening Price  \
# 0          ="0050"       7064552         8298   1034974917         146.00
# 1          ="0051"        135357          185      8244702          60.90
# 2          ="0052"        882163          488    119306921         134.65
# 3          ="0053"         28349           25      1996804          70.25
# 4          ="0054"          3998           13       127031          31.68
# ...            ...           ...          ...          ...            ...
# 1171          9944         71751           38      1459923          20.35
# 1172          9945       6956898         4827    276325555          40.30
# 1173          9946         11298           18       130561          11.45
# 1174          9955        131905          147      2244930          17.05
# 1175          9958       6231522         5543    489629002          81.70
#
#       Highest Price  Lowest Price  Closing Price Dir(+/-)  Change  \
# ...

# %%
ss
# Out:
#      Security Code  Trading Volume  Trading Value  file_date  \
# 0          ="0050"               2         292950 2022-01-03
# 1          ="0051"               0              0 2022-01-03
# 2          ="0052"               0              0 2022-01-03
# 3          ="0053"               0              0 2022-01-03
# 4          ="0054"               0              0 2022-01-03
# ...            ...             ...            ...        ...
# 1118          9944               0              0 2022-10-31
# 1119          9945             173        6891050 2022-10-31
# 1120          9946               0              0 2022-10-31
# 1121          9955               0              0 2022-10-31
# 1122          9958             148       11612400 2022-10-31
#
#      Security Code Clean
# 0                   0050
# 1                   0051
# 2                   0052
# 3                   0053
# 4                   0054
# ...                  ...
# 1118                9944
# ...
