# %% [markdown]
# # 01 - EDA Notebook

# %%
import pandas as pd
import os
import glob

# %%
data_path = os.path.join(os.getcwd(), 'use_this_data', '*')

# %%
files = glob.glob(data_path)

# %%
files
# Out:
# ['/home/ec2-user/SageMaker/udacity-aws-machine-learning-nanodegree-capstone/use_this_data/watchlist_01012022_10312022',
#  '/home/ec2-user/SageMaker/udacity-aws-machine-learning-nanodegree-capstone/use_this_data/ratios_01012022_10312022',
#  '/home/ec2-user/SageMaker/udacity-aws-machine-learning-nanodegree-capstone/use_this_data/stockquotes_01012022_10312022',
#  '/home/ec2-user/SageMaker/udacity-aws-machine-learning-nanodegree-capstone/use_this_data/shortsales_01012022_10312022']

# %%
wl = pd.read_parquet(files[0], columns=['Security Code Clean', 'file_date'])
rat = pd.read_parquet(files[1], columns=['Security Code Clean', 'file_date', 'P/E ratio', 'P/B ratio'])
sq = pd.read_parquet(files[2],  columns=['Security Code Clean', 'file_date', 'Trade Volume', 'Closing Price', 'Change'])
ss = pd.read_parquet(files[3], columns=['Security Code Clean', 'file_date', 'Trading Volume', 'Trading Value'])

# %%
sq
# Out:
#      Security Code Clean  file_date  Trade Volume  Closing Price  Change
# 0                   0050 2022-01-03       7064552         146.40    0.90
# 1                   0051 2022-01-03        135357          60.90    0.10
# 2                   0052 2022-01-03        882163         135.20    1.05
# 3                   0053 2022-01-03         28349          70.45    0.50
# 4                   0054 2022-01-03          3998          31.80    0.12
# ...                  ...        ...           ...            ...     ...
# 1171                9944 2022-10-31         71751          20.40    0.05
# 1172                9945 2022-10-31       6956898          39.60    0.40
# 1173                9946 2022-10-31         11298          11.55    0.05
# 1174                9955 2022-10-31        131905          17.05    0.25
# 1175                9958 2022-10-31       6231522          77.00    3.80
#
# [235301 rows x 5 columns]

# %%
wl
# Out:
#    Security Code Clean  file_date
# 0                 1213 2022-01-03
# 1                 1418 2022-01-03
# 2                 1472 2022-01-03
# 3                 1512 2022-01-03
# 4                 1538 2022-01-03
# ..                 ...        ...
# 8                 3043 2022-10-31
# 9                 3536 2022-10-31
# 10                6225 2022-10-31
# 11                8101 2022-10-31
# 12                9110 2022-10-31
#
# [3440 rows x 2 columns]

# %%
rat
# Out:
#     Security Code Clean  file_date  P/E ratio  P/B ratio
# 0                  1101 2022-01-03      13.91       1.49
# 1                  1102 2022-01-03      10.09       1.03
# 2                  1103 2022-01-03       7.29       0.51
# 3                  1104 2022-01-03      12.78       0.75
# 4                  1108 2022-01-03      20.52       1.06
# ..                  ...        ...        ...        ...
# 960                9944 2022-10-31       4.11       0.66
# 961                9945 2022-10-31       5.34       2.96
# 962                9946 2022-10-31      18.33       0.59
# 963                9955 2022-10-31        NaN       1.21
# 964                9958 2022-10-31      19.35       2.54
#
# [194392 rows x 4 columns]

# %%
ss
# Out:
#      Security Code Clean  file_date  Trading Volume  Trading Value
# 0                   0050 2022-01-03               2         292950
# 1                   0051 2022-01-03               0              0
# 2                   0052 2022-01-03               0              0
# 3                   0053 2022-01-03               0              0
# 4                   0054 2022-01-03               0              0
# ...                  ...        ...             ...            ...
# 1118                9944 2022-10-31               0              0
# 1119                9945 2022-10-31             173        6891050
# 1120                9946 2022-10-31               0              0
# 1121                9955 2022-10-31               0              0
# 1122                9958 2022-10-31             148       11612400
#
# [224945 rows x 4 columns]

# %%
all = pd.merge(left=sq, right=ss, how='left', on=['Security Code Clean', 'file_date'], indicator=True)

# %%
all
# Out:
#        Security Code_x  Trade Volume  Transaction  Trade Value  Opening Price  \
# 0              ="0050"       7064552         8298   1034974917         146.00
# 1              ="0051"        135357          185      8244702          60.90
# 2              ="0052"        882163          488    119306921         134.65
# 3              ="0053"         28349           25      1996804          70.25
# 4              ="0054"          3998           13       127031          31.68
# ...                ...           ...          ...          ...            ...
# 235296            9944         71751           38      1459923          20.35
# 235297            9945       6956898         4827    276325555          40.30
# 235298            9946         11298           18       130561          11.45
# 235299            9955        131905          147      2244930          17.05
# 235300            9958       6231522         5543    489629002          81.70
#
#         Highest Price  Lowest Price  Closing Price Dir(+/-)  Change  ...  \
# 0              147.35        146.00         146.40        +    0.90  ...
# 1               61.30         60.75          60.90        +    0.10  ...
# 2              135.95        134.65         135.20        +    1.05  ...
# 3               70.75         70.25          70.45        +    0.50  ...
# 4               31.80         31.68          31.80        +    0.12  ...
# ...               ...           ...            ...      ...     ...  ...
# 235296          20.40         20.25          20.40        +    0.05  ...
# 235297          40.50         39.25          39.60     None    0.40  ...
# 235298          11.80         11.45          11.55        +    0.05  ...
# 235299          17.10         16.75          17.05        +    0.25  ...
# 235300          81.70         77.00          77.00     None    3.80  ...
#
#         Last Best Bid Volume  Last Best Ask Price  Last Best Ask Volume  \
# 0                         32               146.40                    96
# 1                          2                60.90                    45
# 2                         54               135.35                     7
# 3                         20                70.45                     1
# 4                         24                31.80                     2
# ...                      ...                  ...                   ...
# 235296                     2                20.40                    25
# 235297                    93                39.65                     5
# 235298                     2                11.55                     1
# 235299                     1                17.05                     2
# 235300                     3                77.20                     7
#
#         Price-Earning ratio  file_date Security Code Clean Security Code_y  \
# 0                      0.00 2022-01-03                0050         ="0050"
# 1                      0.00 2022-01-03                0051         ="0051"
# 2                      0.00 2022-01-03                0052         ="0052"
# 3                      0.00 2022-01-03                0053         ="0053"
# 4                      0.00 2022-01-03                0054         ="0054"
# ...                     ...        ...                 ...             ...
# 235296                 4.11 2022-10-31                9944            9944
# 235297                 5.34 2022-10-31                9945            9945
# 235298                18.33 2022-10-31                9946            9946
# 235299                 0.00 2022-10-31                9955            9955
# 235300                19.35 2022-10-31                9958            9958
#
#        Trading Volume  Trading Value  _merge
# 0                   2         292950    both
# 1                   0              0    both
# 2                   0              0    both
# 3                   0              0    both
# 4                   0              0    both
# ...               ...            ...     ...
# 235296              0              0    both
# 235297            173        6891050    both
# 235298              0              0    both
# 235299              0              0    both
# 235300            148       11612400    both
#
# [235301 rows x 21 columns]

# %%
cols = ['Trade Volume', 'Trade Value', 'Closing Price', 'Change', ]
